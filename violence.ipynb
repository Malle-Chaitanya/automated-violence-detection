# %%
import os
import platform
from IPython.display import clear_output
print(platform.platform())

def resolve_dir(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)

def reset_path(Dir):
    if not os.path.exists(Dir):
        os.mkdir(Dir)
    else:
        os.system('rm -f {}/*'.format( Dir))
# Out:
# Windows-10-10.0.22631-SP0

# %%
pip uninstall -y tensorflow tensorflow-intel tensorboard ml-dtypes protobuf
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# Found existing installation: tensorflow_intel 2.18.0
# Uninstalling tensorflow_intel-2.18.0:
#   Successfully uninstalled tensorflow_intel-2.18.0
# Found existing installation: tensorboard 2.18.0
# Uninstalling tensorboard-2.18.0:
#   Successfully uninstalled tensorboard-2.18.0
# Found existing installation: ml-dtypes 0.4.1
# Uninstalling ml-dtypes-0.4.1:
#   Successfully uninstalled ml-dtypes-0.4.1
# Found existing installation: protobuf 3.20.3
# Uninstalling protobuf-3.20.3:
#   Successfully uninstalled protobuf-3.20.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow==2.18.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow==2.18.0
#   Using cached tensorflow-2.18.0-cp310-cp310-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.18.0 (from tensorflow==2.18.0)
#   Using cached tensorflow_intel-2.18.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (24.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 (from tensorflow-intel==2.18.0->tensorflow==2.18.0)
#   Using cached protobuf-5.29.4-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (78.0.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (1.71.0)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-intel==2.18.0->tensorflow==2.18.0)
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.5.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.9.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.13.0)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow-intel==2.18.0->tensorflow==2.18.0)
#   Using cached ml_dtypes-0.4.1-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.45.1)
# Requirement already satisfied: rich in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (13.9.4)
# Requirement already satisfied: namex in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.0.8)
# Requirement already satisfied: optree in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow==2.18.0) (0.1.2)
# Using cached tensorflow-2.18.0-cp310-cp310-win_amd64.whl (7.5 kB)
# Using cached tensorflow_intel-2.18.0-cp310-cp310-win_amd64.whl (390.0 MB)
# Using cached ml_dtypes-0.4.1-cp310-cp310-win_amd64.whl (126 kB)
# Using cached protobuf-5.29.4-cp310-abi3-win_amd64.whl (434 kB)
# Using cached tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
# Installing collected packages: protobuf, ml-dtypes, tensorboard, tensorflow-intel, tensorflow
# Successfully installed ml-dtypes-0.4.1 protobuf-5.29.4 tensorboard-2.18.0 tensorflow-2.18.0 tensorflow-intel-2.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.18.0

# %%
# !pip install protobuf==3.20.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: protobuf==3.20.3 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (3.20.3)

# %%
import os
os.environ['PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION'] = 'python'

# %%
import tensorflow as tf
tf.random.set_seed(73)

# %%
print("Tensorflow version " + tf.__version__)
# Out:
# Tensorflow version 2.18.0

# %%
MyDrive = '/kaggle/working'
PROJECT_DIR = './archive'

# %%
import os
os.listdir(PROJECT_DIR)
# Out:
# ['.ipynb_checkpoints', 'Dataset', 'Real Life Violence Dataset']

# %%
pip install imgaug
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imgaug in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (0.4.0)
# Requirement already satisfied: six in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imgaug) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imgaug) (2.0.2)
# Requirement already satisfied: scipy in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imgaug) (1.15.2)
# Requirement already satisfied: Pillow in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imgaug) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imgaug) (3.10.1)
# Requirement already satisfied: scikit-image>=0.14.2 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imgaug) (0.25.2)
# Requirement already satisfied: opencv-python in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imgaug) (4.11.0.86)
# Requirement already satisfied: imageio in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imgaug) (2.37.0)
# Requirement already satisfied: Shapely in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imgaug) (2.1.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-image>=0.14.2->imgaug) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-image>=0.14.2->imgaug) (2025.3.30)
# Requirement already satisfied: packaging>=21 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-image>=0.14.2->imgaug) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-image>=0.14.2->imgaug) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib->imgaug) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib->imgaug) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib->imgaug) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib->imgaug) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib->imgaug) (2.9.0.post0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install imageio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imageio in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (2.37.0)
# Requirement already satisfied: numpy in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imageio) (2.0.2)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from imageio) (11.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy==1.26.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy==1.26.4 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import os
import imageio
import imgaug.augmenters as iaa
import imgaug as ia

IMG_SIZE = 128
ColorChannels = 3

def video_to_frames(video):
    vidcap = cv2.VideoCapture(video)
    
    import math
    rate = math.floor(vidcap.get(3))
    count = 0
    
    ImageFrames = []
    while vidcap.isOpened():
        ID = vidcap.get(1)
        success, image = vidcap.read()
        
        if success:
            # skipping frames to avoid duplications 
            if (ID % 7 == 0):
                flip = iaa.Fliplr(1.0)
                zoom = iaa.Affine(scale=1.3)
                random_brightness = iaa.Multiply((1, 1.3))
                rotate = iaa.Affine(rotate=(-25, 25))
                
                image_aug = flip(image = image)
                image_aug = random_brightness(image = image_aug)
                image_aug = zoom(image = image_aug)
                image_aug = rotate(image = image_aug)
                
                rgb_img = cv2.cvtColor(image_aug, cv2.COLOR_BGR2RGB)
                resized = cv2.resize(rgb_img, (IMG_SIZE, IMG_SIZE))
                ImageFrames.append(resized)
                
            count += 1
        else:
            break
    
    vidcap.release()
    
    return ImageFrames

# %%
import os
PROJECT_DIR = './archive'

# %%
# !pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from tqdm) (0.4.6)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1

# %%
from tqdm import tqdm

# %%
# %%time
from tqdm import tqdm

VideoDataDir = PROJECT_DIR + '/Dataset'
print('we have \n{} Violence videos \n{} NonViolence videos'.format(
              len(os.listdir(VideoDataDir + '/Violence')), 
              len(os.listdir(VideoDataDir + '/NonViolence'))))

X_original = []
y_original = []

print('i choose 600 videos out of 1200, cuz of memory issue')
CLASSES = ["NonViolence", "Violence"]
#600 <- 300 + 300
# Out:
# we have
# 646 Violence videos
# 645 NonViolence videos
# i choose 600 videos out of 1200, cuz of memory issue
# CPU times: total: 31.2 ms
# Wall time: 10 ms

# %%
for category in os.listdir(VideoDataDir):
    if category not in CLASSES:
        continue  # Skip hidden folders or irrelevant ones like .ipynb_checkpoints

    path = os.path.join(VideoDataDir, category)
    class_num = CLASSES.index(category)

    for i, video in enumerate(tqdm(os.listdir(path)[0:350])):
        video_path = os.path.join(path, video)
        frames = video_to_frames(video_path)
        # Do your processing here...

        for j, frame in enumerate(frames):
            X_original.append(frame)
            y_original.append(class_num)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 350/350 [02:13<00:00,  2.62it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 350/350 [04:08<00:00,  1.41it/s]

# %%
import numpy as np
X_original = np.array(X_original).reshape(-1 , IMG_SIZE * IMG_SIZE * 3)
y_original = np.array(y_original)
len(X_original)
# Out:
# 13336

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.15.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.6.1-cp310-cp310-win_amd64.whl (11.1 MB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 threadpoolctl-3.6.0

# %%
from sklearn.model_selection import StratifiedShuffleSplit

stratified_sample = StratifiedShuffleSplit(n_splits=2, test_size=0.3, random_state=73)

for train_index, test_index in stratified_sample.split(X_original, y_original):
    X_train, X_test = X_original[train_index], X_original[test_index]
    y_train, y_test = y_original[train_index], y_original[test_index]

X_train_nn = X_train.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255
X_test_nn = X_test.reshape(-1, IMG_SIZE, IMG_SIZE, 3) / 255

# %%
import cv2
import os
import numpy as np
import pickle
import matplotlib
matplotlib.use("Agg")

from keras.layers import Input
from keras.models import Model
from keras.layers import Dropout, Flatten, Dense

import matplotlib.pyplot as plt

# %%
epochs = 30
from keras import regularizers
from keras.applications import MobileNetV2  # Import MobileNetV2
from keras.layers import Input, Dense
from keras.models import Model
import tensorflow as tf

kernel_regularizer = regularizers.l2(0.0001)

# Check if TPU is available (Optional, only needed if using TPU)
TPU_INIT = False
try:
    # For Google Colab (Optional, detect TPU availability)
    tpu_devices = tf.config.experimental.list_physical_devices('TPU')
    if tpu_devices:
        tpu_strategy = tf.distribute.TPUStrategy(tpu_devices[0])
        TPU_INIT = True
except:
    TPU_INIT = False

def load_layers():
    input_tensor = Input(shape=(IMG_SIZE, IMG_SIZE, ColorChannels))
    baseModel = MobileNetV2(pooling='avg',
                             include_top=False, 
                             input_tensor=input_tensor)

    headModel = baseModel.output   
    headModel = Dense(1, activation="sigmoid")(headModel)
    model = Model(inputs=baseModel.input, outputs=headModel)

    # Freeze base model layers
    for layer in baseModel.layers:
        layer.trainable = False

    print("Compiling model...")
    model.compile(loss="binary_crossentropy",
                  optimizer='adam',
                  metrics=["accuracy"])

    return model

if TPU_INIT:
    with tpu_strategy.scope():
        model = load_layers()
else:
    model = load_layers()

model.summary()  # Display the model summary
# Out:
# C:\Users\Vyshnavi Malle\AppData\Local\Temp\ipykernel_21288\1934079316.py:23: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   baseModel = MobileNetV2(pooling='avg',
# Compiling model...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 128, 128, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 64, 64, 32)        │             864 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bn_Conv1 (BatchNormalization) │ (None, 64, 64, 32)        │             128 │ Conv1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1_relu (ReLU)             │ (None, 64, 64, 32)        │               0 │ bn_Conv1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_depthwise       │ (None, 64, 64, 32)        │             288 │ Conv1_relu[0][0]           │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_depthwise_BN    │ (None, 64, 64, 32)        │             128 │ expanded_conv_depthwise[0… │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_depthwise_relu  │ (None, 64, 64, 32)        │               0 │ expanded_conv_depthwise_B… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_project         │ (None, 64, 64, 16)        │             512 │ expanded_conv_depthwise_r… │
# │ (Conv2D)                      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_project_BN      │ (None, 64, 64, 16)        │              64 │ expanded_conv_project[0][… │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_expand (Conv2D)       │ (None, 64, 64, 96)        │           1,536 │ expanded_conv_project_BN[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_expand_BN             │ (None, 64, 64, 96)        │             384 │ block_1_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_expand_relu (ReLU)    │ (None, 64, 64, 96)        │               0 │ block_1_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_pad (ZeroPadding2D)   │ (None, 65, 65, 96)        │               0 │ block_1_expand_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_depthwise             │ (None, 32, 32, 96)        │             864 │ block_1_pad[0][0]          │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_depthwise_BN          │ (None, 32, 32, 96)        │             384 │ block_1_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_depthwise_relu (ReLU) │ (None, 32, 32, 96)        │               0 │ block_1_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_project (Conv2D)      │ (None, 32, 32, 24)        │           2,304 │ block_1_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_project_BN            │ (None, 32, 32, 24)        │              96 │ block_1_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_expand (Conv2D)       │ (None, 32, 32, 144)       │           3,456 │ block_1_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_expand_BN             │ (None, 32, 32, 144)       │             576 │ block_2_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_expand_relu (ReLU)    │ (None, 32, 32, 144)       │               0 │ block_2_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_depthwise             │ (None, 32, 32, 144)       │           1,296 │ block_2_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_depthwise_BN          │ (None, 32, 32, 144)       │             576 │ block_2_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_depthwise_relu (ReLU) │ (None, 32, 32, 144)       │               0 │ block_2_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_project (Conv2D)      │ (None, 32, 32, 24)        │           3,456 │ block_2_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_project_BN            │ (None, 32, 32, 24)        │              96 │ block_2_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_add (Add)             │ (None, 32, 32, 24)        │               0 │ block_1_project_BN[0][0],  │
# │                               │                           │                 │ block_2_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_expand (Conv2D)       │ (None, 32, 32, 144)       │           3,456 │ block_2_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_expand_BN             │ (None, 32, 32, 144)       │             576 │ block_3_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_expand_relu (ReLU)    │ (None, 32, 32, 144)       │               0 │ block_3_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_pad (ZeroPadding2D)   │ (None, 33, 33, 144)       │               0 │ block_3_expand_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_depthwise             │ (None, 16, 16, 144)       │           1,296 │ block_3_pad[0][0]          │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_depthwise_BN          │ (None, 16, 16, 144)       │             576 │ block_3_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_depthwise_relu (ReLU) │ (None, 16, 16, 144)       │               0 │ block_3_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_project (Conv2D)      │ (None, 16, 16, 32)        │           4,608 │ block_3_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_project_BN            │ (None, 16, 16, 32)        │             128 │ block_3_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_expand (Conv2D)       │ (None, 16, 16, 192)       │           6,144 │ block_3_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_expand_BN             │ (None, 16, 16, 192)       │             768 │ block_4_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_expand_relu (ReLU)    │ (None, 16, 16, 192)       │               0 │ block_4_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_depthwise             │ (None, 16, 16, 192)       │           1,728 │ block_4_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_depthwise_BN          │ (None, 16, 16, 192)       │             768 │ block_4_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_depthwise_relu (ReLU) │ (None, 16, 16, 192)       │               0 │ block_4_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_project (Conv2D)      │ (None, 16, 16, 32)        │           6,144 │ block_4_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_project_BN            │ (None, 16, 16, 32)        │             128 │ block_4_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_add (Add)             │ (None, 16, 16, 32)        │               0 │ block_3_project_BN[0][0],  │
# │                               │                           │                 │ block_4_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_expand (Conv2D)       │ (None, 16, 16, 192)       │           6,144 │ block_4_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_expand_BN             │ (None, 16, 16, 192)       │             768 │ block_5_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_expand_relu (ReLU)    │ (None, 16, 16, 192)       │               0 │ block_5_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_depthwise             │ (None, 16, 16, 192)       │           1,728 │ block_5_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_depthwise_BN          │ (None, 16, 16, 192)       │             768 │ block_5_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_depthwise_relu (ReLU) │ (None, 16, 16, 192)       │               0 │ block_5_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_project (Conv2D)      │ (None, 16, 16, 32)        │           6,144 │ block_5_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_project_BN            │ (None, 16, 16, 32)        │             128 │ block_5_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_add (Add)             │ (None, 16, 16, 32)        │               0 │ block_4_add[0][0],         │
# │                               │                           │                 │ block_5_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_expand (Conv2D)       │ (None, 16, 16, 192)       │           6,144 │ block_5_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_expand_BN             │ (None, 16, 16, 192)       │             768 │ block_6_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_expand_relu (ReLU)    │ (None, 16, 16, 192)       │               0 │ block_6_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_pad (ZeroPadding2D)   │ (None, 17, 17, 192)       │               0 │ block_6_expand_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_depthwise             │ (None, 8, 8, 192)         │           1,728 │ block_6_pad[0][0]          │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_depthwise_BN          │ (None, 8, 8, 192)         │             768 │ block_6_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_depthwise_relu (ReLU) │ (None, 8, 8, 192)         │               0 │ block_6_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_project (Conv2D)      │ (None, 8, 8, 64)          │          12,288 │ block_6_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_project_BN            │ (None, 8, 8, 64)          │             256 │ block_6_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_expand (Conv2D)       │ (None, 8, 8, 384)         │          24,576 │ block_6_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_expand_BN             │ (None, 8, 8, 384)         │           1,536 │ block_7_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_expand_relu (ReLU)    │ (None, 8, 8, 384)         │               0 │ block_7_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_depthwise             │ (None, 8, 8, 384)         │           3,456 │ block_7_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_depthwise_BN          │ (None, 8, 8, 384)         │           1,536 │ block_7_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_depthwise_relu (ReLU) │ (None, 8, 8, 384)         │               0 │ block_7_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_project (Conv2D)      │ (None, 8, 8, 64)          │          24,576 │ block_7_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_project_BN            │ (None, 8, 8, 64)          │             256 │ block_7_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_add (Add)             │ (None, 8, 8, 64)          │               0 │ block_6_project_BN[0][0],  │
# │                               │                           │                 │ block_7_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_expand (Conv2D)       │ (None, 8, 8, 384)         │          24,576 │ block_7_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_expand_BN             │ (None, 8, 8, 384)         │           1,536 │ block_8_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_expand_relu (ReLU)    │ (None, 8, 8, 384)         │               0 │ block_8_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_depthwise             │ (None, 8, 8, 384)         │           3,456 │ block_8_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_depthwise_BN          │ (None, 8, 8, 384)         │           1,536 │ block_8_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_depthwise_relu (ReLU) │ (None, 8, 8, 384)         │               0 │ block_8_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_project (Conv2D)      │ (None, 8, 8, 64)          │          24,576 │ block_8_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_project_BN            │ (None, 8, 8, 64)          │             256 │ block_8_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_add (Add)             │ (None, 8, 8, 64)          │               0 │ block_7_add[0][0],         │
# │                               │                           │                 │ block_8_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_expand (Conv2D)       │ (None, 8, 8, 384)         │          24,576 │ block_8_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_expand_BN             │ (None, 8, 8, 384)         │           1,536 │ block_9_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_expand_relu (ReLU)    │ (None, 8, 8, 384)         │               0 │ block_9_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_depthwise             │ (None, 8, 8, 384)         │           3,456 │ block_9_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_depthwise_BN          │ (None, 8, 8, 384)         │           1,536 │ block_9_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_depthwise_relu (ReLU) │ (None, 8, 8, 384)         │               0 │ block_9_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_project (Conv2D)      │ (None, 8, 8, 64)          │          24,576 │ block_9_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_project_BN            │ (None, 8, 8, 64)          │             256 │ block_9_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_add (Add)             │ (None, 8, 8, 64)          │               0 │ block_8_add[0][0],         │
# │                               │                           │                 │ block_9_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_expand (Conv2D)      │ (None, 8, 8, 384)         │          24,576 │ block_9_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_expand_BN            │ (None, 8, 8, 384)         │           1,536 │ block_10_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_expand_relu (ReLU)   │ (None, 8, 8, 384)         │               0 │ block_10_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_depthwise            │ (None, 8, 8, 384)         │           3,456 │ block_10_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_depthwise_BN         │ (None, 8, 8, 384)         │           1,536 │ block_10_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_depthwise_relu       │ (None, 8, 8, 384)         │               0 │ block_10_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_project (Conv2D)     │ (None, 8, 8, 96)          │          36,864 │ block_10_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_project_BN           │ (None, 8, 8, 96)          │             384 │ block_10_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_expand (Conv2D)      │ (None, 8, 8, 576)         │          55,296 │ block_10_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_expand_BN            │ (None, 8, 8, 576)         │           2,304 │ block_11_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_expand_relu (ReLU)   │ (None, 8, 8, 576)         │               0 │ block_11_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_depthwise            │ (None, 8, 8, 576)         │           5,184 │ block_11_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_depthwise_BN         │ (None, 8, 8, 576)         │           2,304 │ block_11_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_depthwise_relu       │ (None, 8, 8, 576)         │               0 │ block_11_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_project (Conv2D)     │ (None, 8, 8, 96)          │          55,296 │ block_11_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_project_BN           │ (None, 8, 8, 96)          │             384 │ block_11_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_add (Add)            │ (None, 8, 8, 96)          │               0 │ block_10_project_BN[0][0], │
# │                               │                           │                 │ block_11_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_expand (Conv2D)      │ (None, 8, 8, 576)         │          55,296 │ block_11_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_expand_BN            │ (None, 8, 8, 576)         │           2,304 │ block_12_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_expand_relu (ReLU)   │ (None, 8, 8, 576)         │               0 │ block_12_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_depthwise            │ (None, 8, 8, 576)         │           5,184 │ block_12_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_depthwise_BN         │ (None, 8, 8, 576)         │           2,304 │ block_12_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_depthwise_relu       │ (None, 8, 8, 576)         │               0 │ block_12_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_project (Conv2D)     │ (None, 8, 8, 96)          │          55,296 │ block_12_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_project_BN           │ (None, 8, 8, 96)          │             384 │ block_12_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_add (Add)            │ (None, 8, 8, 96)          │               0 │ block_11_add[0][0],        │
# │                               │                           │                 │ block_12_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_expand (Conv2D)      │ (None, 8, 8, 576)         │          55,296 │ block_12_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_expand_BN            │ (None, 8, 8, 576)         │           2,304 │ block_13_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_expand_relu (ReLU)   │ (None, 8, 8, 576)         │               0 │ block_13_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_pad (ZeroPadding2D)  │ (None, 9, 9, 576)         │               0 │ block_13_expand_relu[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_depthwise            │ (None, 4, 4, 576)         │           5,184 │ block_13_pad[0][0]         │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_depthwise_BN         │ (None, 4, 4, 576)         │           2,304 │ block_13_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_depthwise_relu       │ (None, 4, 4, 576)         │               0 │ block_13_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_project (Conv2D)     │ (None, 4, 4, 160)         │          92,160 │ block_13_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_project_BN           │ (None, 4, 4, 160)         │             640 │ block_13_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_expand (Conv2D)      │ (None, 4, 4, 960)         │         153,600 │ block_13_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_expand_BN            │ (None, 4, 4, 960)         │           3,840 │ block_14_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_expand_relu (ReLU)   │ (None, 4, 4, 960)         │               0 │ block_14_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_depthwise            │ (None, 4, 4, 960)         │           8,640 │ block_14_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_depthwise_BN         │ (None, 4, 4, 960)         │           3,840 │ block_14_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_depthwise_relu       │ (None, 4, 4, 960)         │               0 │ block_14_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_project (Conv2D)     │ (None, 4, 4, 160)         │         153,600 │ block_14_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_project_BN           │ (None, 4, 4, 160)         │             640 │ block_14_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_add (Add)            │ (None, 4, 4, 160)         │               0 │ block_13_project_BN[0][0], │
# │                               │                           │                 │ block_14_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_expand (Conv2D)      │ (None, 4, 4, 960)         │         153,600 │ block_14_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_expand_BN            │ (None, 4, 4, 960)         │           3,840 │ block_15_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_expand_relu (ReLU)   │ (None, 4, 4, 960)         │               0 │ block_15_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_depthwise            │ (None, 4, 4, 960)         │           8,640 │ block_15_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_depthwise_BN         │ (None, 4, 4, 960)         │           3,840 │ block_15_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_depthwise_relu       │ (None, 4, 4, 960)         │               0 │ block_15_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_project (Conv2D)     │ (None, 4, 4, 160)         │         153,600 │ block_15_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_project_BN           │ (None, 4, 4, 160)         │             640 │ block_15_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_add (Add)            │ (None, 4, 4, 160)         │               0 │ block_14_add[0][0],        │
# │                               │                           │                 │ block_15_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_expand (Conv2D)      │ (None, 4, 4, 960)         │         153,600 │ block_15_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_expand_BN            │ (None, 4, 4, 960)         │           3,840 │ block_16_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_expand_relu (ReLU)   │ (None, 4, 4, 960)         │               0 │ block_16_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_depthwise            │ (None, 4, 4, 960)         │           8,640 │ block_16_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_depthwise_BN         │ (None, 4, 4, 960)         │           3,840 │ block_16_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_depthwise_relu       │ (None, 4, 4, 960)         │               0 │ block_16_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_project (Conv2D)     │ (None, 4, 4, 320)         │         307,200 │ block_16_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_project_BN           │ (None, 4, 4, 320)         │           1,280 │ block_16_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv_1 (Conv2D)               │ (None, 4, 4, 1280)        │         409,600 │ block_16_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv_1_bn                     │ (None, 4, 4, 1280)        │           5,120 │ Conv_1[0][0]               │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ out_relu (ReLU)               │ (None, 4, 4, 1280)        │               0 │ Conv_1_bn[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d      │ (None, 1280)              │               0 │ out_relu[0][0]             │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 1)                 │           1,281 │ global_average_pooling2d[… │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,259,265 (8.62 MB)
#  Trainable params: 1,281 (5.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
from tensorflow.keras.callbacks import Callback, ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping, ReduceLROnPlateau

patience = 3

start_lr = 0.00001
min_lr = 0.00001
max_lr = 0.00005

batch_size = 4

if TPU_INIT:
    max_lr = max_lr * tpu_strategy.num_replicas_in_sync
    batch_size = batch_size * tpu_strategy.num_replicas_in_sync

rampup_epochs = 5
sustain_epochs = 0
exp_decay = .8

def lrfn(epoch):
    if epoch < rampup_epochs:
        return (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
        return max_lr
    else:
        return (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr


class myCallback(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if ((logs.get('accuracy')>=0.999)):
            print("\nLimits Reached cancelling training!")
            self.model.stop_training = True

# %%
MyDrive = r"C:\Users\Vyshnavi Malle\Desktop\final_project"

# %%
end_callback = myCallback()

lr_callback = LearningRateScheduler(lambda epoch: lrfn(epoch), verbose=False)

early_stopping = EarlyStopping(patience = patience, monitor='val_loss',
                                 mode='min', restore_best_weights=True, 
                                 verbose = 1, min_delta = .00075)

PROJECT_DIR = MyDrive + '/RiskDetection'

lr_plat = ReduceLROnPlateau(patience = 2, mode = 'min')

os.system('rm -rf ./logs/')

import datetime
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = TensorBoard(log_dir = log_dir, write_graph=True, histogram_freq=1)

checkpoint_filepath = 'ModelWeights.weights.h5'

model_checkpoints = ModelCheckpoint(filepath=checkpoint_filepath,
                                        save_weights_only=True,
                                        monitor='val_loss',
                                        mode='min',
                                        verbose = 1,
                                        save_best_only=True)


callbacks = [end_callback, lr_callback, model_checkpoints, tensorboard_callback, early_stopping, lr_plat]

if TPU_INIT:
    callbacks = [end_callback, lr_callback, model_checkpoints, early_stopping, lr_plat]

# %%
print('Training head...')
#model.load_weights('./Model_Weights.h5')

history = model.fit(X_train_nn ,y_train, epochs=epochs,
                        callbacks=callbacks,
                        validation_data = (X_test_nn, y_test),
                        batch_size=batch_size)

print('\nRestoring best Weights for MobileNetV2')
model.load_weights(checkpoint_filepath)
# Out:
# Training head...
# Epoch 1/30
# C:\Users\Vyshnavi Malle\AppData\Roaming\Python\Python310\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 128, 128, 3))
#   warnings.warn(msg)
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5485 - loss: 0.8524
# Epoch 1: val_loss improved from inf to 0.65798, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 181s 73ms/step - accuracy: 0.5486 - loss: 0.8524 - val_accuracy: 0.6323 - val_loss: 0.6580 - learning_rate: 1.0000e-05
# Epoch 2/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.6755 - loss: 0.6039
# Epoch 2: val_loss improved from 0.65798 to 0.48166, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 147s 63ms/step - accuracy: 0.6756 - loss: 0.6038 - val_accuracy: 0.7738 - val_loss: 0.4817 - learning_rate: 1.8000e-05
# Epoch 3/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8061 - loss: 0.4406
# Epoch 3: val_loss improved from 0.48166 to 0.38585, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 147s 63ms/step - accuracy: 0.8061 - loss: 0.4406 - val_accuracy: 0.8323 - val_loss: 0.3858 - learning_rate: 2.6000e-05
# Epoch 4/30
# 2333/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8489 - loss: 0.3602
# Epoch 4: val_loss improved from 0.38585 to 0.33356, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 146s 62ms/step - accuracy: 0.8489 - loss: 0.3602 - val_accuracy: 0.8630 - val_loss: 0.3336 - learning_rate: 3.4000e-05
# Epoch 5/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8781 - loss: 0.3098
# Epoch 5: val_loss improved from 0.33356 to 0.30071, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 145s 62ms/step - accuracy: 0.8781 - loss: 0.3098 - val_accuracy: 0.8775 - val_loss: 0.3007 - learning_rate: 4.2000e-05
# Epoch 6/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8954 - loss: 0.2745
# Epoch 6: val_loss improved from 0.30071 to 0.27727, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 146s 62ms/step - accuracy: 0.8954 - loss: 0.2745 - val_accuracy: 0.8875 - val_loss: 0.2773 - learning_rate: 5.0000e-05
# Epoch 7/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9095 - loss: 0.2474
# Epoch 7: val_loss improved from 0.27727 to 0.26311, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 146s 63ms/step - accuracy: 0.9095 - loss: 0.2474 - val_accuracy: 0.8953 - val_loss: 0.2631 - learning_rate: 4.2000e-05
# Epoch 8/30
# 2333/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9083 - loss: 0.2483
# Epoch 8: val_loss improved from 0.26311 to 0.25432, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 146s 62ms/step - accuracy: 0.9083 - loss: 0.2483 - val_accuracy: 0.8975 - val_loss: 0.2543 - learning_rate: 3.5600e-05
# Epoch 9/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9132 - loss: 0.2291
# Epoch 9: val_loss improved from 0.25432 to 0.24843, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 164s 70ms/step - accuracy: 0.9132 - loss: 0.2291 - val_accuracy: 0.9030 - val_loss: 0.2484 - learning_rate: 3.0480e-05
# Epoch 10/30
# 2333/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9201 - loss: 0.2177
# Epoch 10: val_loss improved from 0.24843 to 0.24481, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 165s 71ms/step - accuracy: 0.9201 - loss: 0.2177 - val_accuracy: 0.9038 - val_loss: 0.2448 - learning_rate: 2.6384e-05
# Epoch 11/30
# 2333/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9240 - loss: 0.2114
# Epoch 11: val_loss improved from 0.24481 to 0.24033, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 161s 69ms/step - accuracy: 0.9240 - loss: 0.2114 - val_accuracy: 0.9063 - val_loss: 0.2403 - learning_rate: 2.3107e-05
# Epoch 12/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9180 - loss: 0.2165
# Epoch 12: val_loss improved from 0.24033 to 0.23821, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 159s 68ms/step - accuracy: 0.9180 - loss: 0.2165 - val_accuracy: 0.9060 - val_loss: 0.2382 - learning_rate: 2.0486e-05
# Epoch 13/30
# 2333/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9246 - loss: 0.2092
# Epoch 13: val_loss improved from 0.23821 to 0.23675, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 158s 68ms/step - accuracy: 0.9246 - loss: 0.2092 - val_accuracy: 0.9065 - val_loss: 0.2367 - learning_rate: 1.8389e-05
# Epoch 14/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9227 - loss: 0.2052
# Epoch 14: val_loss improved from 0.23675 to 0.23323, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 136s 58ms/step - accuracy: 0.9227 - loss: 0.2052 - val_accuracy: 0.9090 - val_loss: 0.2332 - learning_rate: 1.6711e-05
# Epoch 15/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9250 - loss: 0.2011
# Epoch 15: val_loss improved from 0.23323 to 0.23192, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 127s 54ms/step - accuracy: 0.9250 - loss: 0.2011 - val_accuracy: 0.9095 - val_loss: 0.2319 - learning_rate: 1.5369e-05
# Epoch 16/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9296 - loss: 0.1968
# Epoch 16: val_loss improved from 0.23192 to 0.23006, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 130s 56ms/step - accuracy: 0.9295 - loss: 0.1968 - val_accuracy: 0.9105 - val_loss: 0.2301 - learning_rate: 1.4295e-05
# Epoch 17/30
# 2333/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9265 - loss: 0.1974
# Epoch 17: val_loss improved from 0.23006 to 0.22856, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 126s 54ms/step - accuracy: 0.9265 - loss: 0.1974 - val_accuracy: 0.9115 - val_loss: 0.2286 - learning_rate: 1.3436e-05
# Epoch 18/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9238 - loss: 0.2033
# Epoch 18: val_loss improved from 0.22856 to 0.22728, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 133s 57ms/step - accuracy: 0.9238 - loss: 0.2033 - val_accuracy: 0.9118 - val_loss: 0.2273 - learning_rate: 1.2749e-05
# Epoch 19/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9291 - loss: 0.1950
# Epoch 19: val_loss improved from 0.22728 to 0.22599, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 129s 55ms/step - accuracy: 0.9291 - loss: 0.1950 - val_accuracy: 0.9133 - val_loss: 0.2260 - learning_rate: 1.2199e-05
# Epoch 20/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9272 - loss: 0.1971
# Epoch 20: val_loss improved from 0.22599 to 0.22492, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 132s 57ms/step - accuracy: 0.9272 - loss: 0.1971 - val_accuracy: 0.9135 - val_loss: 0.2249 - learning_rate: 1.1759e-05
# Epoch 21/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9318 - loss: 0.1958
# Epoch 21: val_loss improved from 0.22492 to 0.22400, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 133s 57ms/step - accuracy: 0.9318 - loss: 0.1958 - val_accuracy: 0.9123 - val_loss: 0.2240 - learning_rate: 1.1407e-05
# Epoch 22/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9287 - loss: 0.1922
# Epoch 22: val_loss improved from 0.22400 to 0.22289, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 134s 57ms/step - accuracy: 0.9287 - loss: 0.1922 - val_accuracy: 0.9143 - val_loss: 0.2229 - learning_rate: 1.1126e-05
# Epoch 23/30
# 2333/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.9308 - loss: 0.1951
# Epoch 23: val_loss improved from 0.22289 to 0.22210, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 132s 56ms/step - accuracy: 0.9308 - loss: 0.1951 - val_accuracy: 0.9150 - val_loss: 0.2221 - learning_rate: 1.0901e-05
# Epoch 24/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9284 - loss: 0.1934
# Epoch 24: val_loss improved from 0.22210 to 0.22172, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 138s 59ms/step - accuracy: 0.9284 - loss: 0.1934 - val_accuracy: 0.9150 - val_loss: 0.2217 - learning_rate: 1.0721e-05
# Epoch 25/30
# 2333/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9279 - loss: 0.1944
# Epoch 25: val_loss improved from 0.22172 to 0.22038, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 137s 59ms/step - accuracy: 0.9280 - loss: 0.1944 - val_accuracy: 0.9158 - val_loss: 0.2204 - learning_rate: 1.0576e-05
# Epoch 26/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9303 - loss: 0.1869
# Epoch 26: val_loss improved from 0.22038 to 0.21956, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 147s 63ms/step - accuracy: 0.9303 - loss: 0.1869 - val_accuracy: 0.9158 - val_loss: 0.2196 - learning_rate: 1.0461e-05
# Epoch 27/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9314 - loss: 0.1887
# Epoch 27: val_loss improved from 0.21956 to 0.21888, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 148s 63ms/step - accuracy: 0.9314 - loss: 0.1887 - val_accuracy: 0.9165 - val_loss: 0.2189 - learning_rate: 1.0369e-05
# Epoch 28/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9264 - loss: 0.1903
# Epoch 28: val_loss improved from 0.21888 to 0.21800, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 141s 60ms/step - accuracy: 0.9264 - loss: 0.1903 - val_accuracy: 0.9153 - val_loss: 0.2180 - learning_rate: 1.0295e-05
# Epoch 29/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9344 - loss: 0.1822
# Epoch 29: val_loss improved from 0.21800 to 0.21742, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 141s 60ms/step - accuracy: 0.9344 - loss: 0.1822 - val_accuracy: 0.9165 - val_loss: 0.2174 - learning_rate: 1.0236e-05
# Epoch 30/30
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9322 - loss: 0.1881
# Epoch 30: val_loss improved from 0.21742 to 0.21677, saving model to ModelWeights.weights.h5
# 2334/2334 ━━━━━━━━━━━━━━━━━━━━ 137s 59ms/step - accuracy: 0.9322 - loss: 0.1881 - val_accuracy: 0.9165 - val_loss: 0.2168 - learning_rate: 1.0189e-05
# Restoring model weights from the end of the best epoch: 30.
#
# Restoring best Weights for MobileNetV2

# %%
# %matplotlib inline

def print_graph(item, index, history):
    plt.figure()
    train_values = history.history[item][0:index]
    plt.plot(train_values)
    test_values = history.history['val_' + item][0:index]
    plt.plot(test_values)
    plt.legend(['training','validation'])
    plt.title('Training and validation '+ item)
    plt.xlabel('epoch')
    plt.show()
    plot = '{}.png'.format(item)
    plt.savefig(plot)


def get_best_epoch(test_loss, history):
    for key, item in enumerate(history.history.items()):
        (name, arr) = item
        if name == 'val_loss':
            for i in range(len(arr)):
                if round(test_loss, 2) == round(arr[i], 2):
                    return i
                
def model_summary(model, history):
    print('---'*30)
    test_loss, test_accuracy = model.evaluate(X_test_nn, y_test, verbose=0)

    if history:
        index = get_best_epoch(test_loss, history)
        print('Best Epochs: ', index)

        train_accuracy = history.history['accuracy'][index]
        train_loss = history.history['loss'][index]

        print('Accuracy on train:',train_accuracy,'\tLoss on train:',train_loss)
        print('Accuracy on test:',test_accuracy,'\tLoss on test:',test_loss)
        print_graph('loss', index, history)
        print_graph('accuracy', index, history)
        print('---'*30)

# %%
model_summary(model, history)
# Out:
# ------------------------------------------------------------------------------------------
# Best Epochs:  19
# Accuracy on train: 0.9292983412742615 	Loss on train: 0.19497883319854736
# Accuracy on test: 0.916520893573761 	Loss on test: 0.21676522493362427
# ------------------------------------------------------------------------------------------

# %%
# evaluate the network
print("Evaluating network...")
predictions = model.predict(X_test_nn)
preds = predictions > 0.5
# Out:
# Evaluating network...
# C:\Users\Vyshnavi Malle\AppData\Roaming\Python\Python310\site-packages\keras\src\models\functional.py:238: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 128, 128, 3))
#   warnings.warn(msg)
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 31s 222ms/step

# %%
pip install scikit-learn==1.1.3
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/scikit-learn/
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Vyshnavi Malle\AppData\Roaming\Python\Python310\site-packages\~klearn'.
#   You can safely remove it manually.
# Collecting scikit-learn==1.1.3
#   Using cached scikit_learn-1.1.3-cp310-cp310-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-learn==1.1.3) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-learn==1.1.3) (1.15.2)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-learn==1.1.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from scikit-learn==1.1.3) (3.6.0)
# Using cached scikit_learn-1.1.3-cp310-cp310-win_amd64.whl (7.5 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# Successfully installed scikit-learn-1.1.3

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
# !pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from seaborn) (1.26.4)
# Collecting pandas>=1.2 (from seaborn)
#   Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.2->seaborn)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.2->seaborn)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\vyshnavi malle\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas, seaborn
# Successfully installed pandas-2.2.3 pytz-2025.2 seaborn-0.13.2 tzdata-2025.2

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score, classification_report, confusion_matrix

# Compute confusion matrix
corr_pred = metrics.confusion_matrix(y_test, preds)

# Correct and wrong predictions
n_correct = np.int32((corr_pred[0][0] + corr_pred[1][1]))
print('> Correct Predictions:', n_correct)
n_wrongs = np.int32((corr_pred[0][1] + corr_pred[1][0]))
print('> Wrong Predictions:', n_wrongs)

# Plot heatmap
sns.heatmap(corr_pred, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()

# Classification report
print(metrics.classification_report(y_test, preds, target_names=["NonViolence", "Violence"]))
# Out:
# > Correct Predictions: 3667
# > Wrong Predictions: 334
#               precision    recall  f1-score   support
#
#  NonViolence       0.92      0.88      0.90      1736
#     Violence       0.91      0.94      0.93      2265
#
#     accuracy                           0.92      4001
#    macro avg       0.92      0.91      0.91      4001
# weighted avg       0.92      0.92      0.92      4001

# %%
args_model = "modelnew.h5"
model.save(args_model)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
